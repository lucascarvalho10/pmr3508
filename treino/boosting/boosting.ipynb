# %% [markdown]
# # PMR3508 - Aprendizado de Máquina e Reconhecimento de Padrões

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.inspection import DecisionBoundaryDisplay

# %%
X, y = make_classification(n_samples=500, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = GradientBoostingClassifier(n_estimators=50, learning_rate=0.1, max_depth=3, random_state=42)
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(n_estimators=50, random_state=42)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia no conjunto de teste: {accuracy:.2f}")
# Out:
# Acurácia no conjunto de teste: 0.95

# %%
plt.figure(figsize=(12, 6))
DecisionBoundaryDisplay.from_estimator(model, X, cmap='coolwarm', alpha=0.5)

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', s=50, edgecolor='k', label="Dados de Treinamento")
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='coolwarm', s=100, marker='*', edgecolor='k', label="Dados de Teste")

# 6. Configurar e exibir o gráfico
plt.title("Gradient Boosting - Limite de Decisão")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.legend()
plt.show()
