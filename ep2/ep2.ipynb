# %% [markdown]
# # PMR3508 - Aprendizado de Máquina e Reconhecimento de Padrões (2024)

# %% [markdown]
# ## Segundo Exercício-Programa
#
# O objetivo deste exercício é comparar diferentes *classificadores* e *regressores*, todos testados no mesmo conjunto de dados, a Base Adult
#
# Lucas Carvalho, 2024

# %% [markdown]
# ### Preparação do Ambiente

# %%
# Biblitoecas Base
import pandas as pd
import matplotlib.pyplot as plt

# Modelos utilizados
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %% [markdown]
# ### Importação e Tratamento dos Dados

# %% [markdown]
# #### Importação
#
# Primeiramente, importação dos dados, levando em consideração uma melhor nomenclatura de cada uma das Features, facilitando o entendimento do código

# %%
trainData = pd.read_csv(
    "./input/train_data.csv",
    na_values= '?',
    index_col= ['Id'],
    header= 0,
    names= [
        "Id",
        "Age",
        "Workclass",
        "Fnlwgt",
        "Education",
        "Education-num",
        "Marital-status",
        "Occupation",
        "Relationship",
        "Race",
        "Sex",
        "Capital-gain",
        "Capital-loss",
        "Hours-per-week",
        "Native-country",
        "Target"
    ]
)

testData = pd.read_csv(
    "./input/test_data.csv",
    na_values= '?',
    index_col= ['Id'],
    header= 0,
    names= [
        "Id",
        "Age",
        "Workclass",
        "Fnlwgt",
        "Education",
        "Education-num",
        "Marital-status",
        "Occupation",
        "Relationship",
        "Race",
        "Sex",
        "Capital-gain",
        "Capital-loss",
        "Hours-per-week",
        "Native-country"
    ]
)

# %% [markdown]
# #### Tratamento

# %% [markdown]
# Como o objetivo é comparar classificadores, será considerado o mesmo tratamento de dados feito anteriormente em relação ao KNN. Nota-se que houve aplicação de diferentes encoders, assim como ordenação binária

# %%
# Preenchendo valores nulos em 'Workclass' e fazendo o mapeamento
trainData["Workclass"] = trainData["Workclass"].fillna("Private")
trainData["Workclass"] = trainData["Workclass"].apply(lambda x: 1 if x == "Private" else 0)
trainData.rename(columns={"Workclass": "isPrivate"}, inplace=True)

# Removendo valores nulos em 'Occupation' e criando variáveis dummies
trainData = trainData.dropna(subset=["Occupation"])
trainData = pd.concat([trainData, pd.get_dummies(trainData["Occupation"], prefix="Occ")], axis=1)
trainData = trainData.drop("Occupation", axis=1)

# Mapeando 'Native-country'
trainData["Native-country"] = trainData["Native-country"].apply(lambda x: 1 if x == "United-States" else 0)
trainData.rename(columns={"Native-country": "isFromUS"}, inplace=True)

# Criando variáveis dummies para 'Marital-status', 'Relationship', 'Race'
trainData = pd.concat([trainData, pd.get_dummies(trainData["Marital-status"], prefix="Mar")], axis=1)
trainData = trainData.drop("Marital-status", axis=1)

trainData = pd.concat([trainData, pd.get_dummies(trainData["Relationship"], prefix="Rel")], axis=1)
trainData = trainData.drop("Relationship", axis=1)

trainData = pd.concat([trainData, pd.get_dummies(trainData["Race"], prefix="Race")], axis=1)
trainData = trainData.drop("Race", axis=1)

# Mapeando 'Sex'
trainData["Sex"] = trainData["Sex"].apply(lambda x: 1.0 if x == "Male" else 0.0)
trainData.rename(columns={"Sex": "isMale"}, inplace=True)

# Mapeando 'Target'
trainData["Target"] = trainData["Target"].apply(lambda x: 1.0 if x == ">50K" else 0.0)

trainData_dummies = pd.get_dummies(trainData, drop_first=True)

# %% [markdown]
# Mostrando o resultado do DataFrame após as operações indicadas

# %%
trainData
# Out:
#        Age  isPrivate  Fnlwgt     Education  Education-num  isMale  \
# Id
# 16280   34          1  204991  Some-college             10     1.0
# 16281   58          0  310085          10th              6     1.0
# 16282   25          1  146117  Some-college             10     1.0
# 16283   24          1  138938  Some-college             10     0.0
# 16284   57          0  258883       HS-grad              9     1.0
# ...    ...        ...     ...           ...            ...     ...
# 48835   42          1  384236       Masters             14     1.0
# 48836   23          1  129042       HS-grad              9     0.0
# 48837   30          1  195488       HS-grad              9     0.0
# 48838   18          1   27620       HS-grad              9     0.0
# 48839   47          0  203067     Bachelors             13     1.0
#
#        Capital-gain  Capital-loss  Hours-per-week  isFromUS  ...  \
# Id                                                           ...
# 16280             0             0              44         1  ...
# 16281             0             0              40         1  ...
# 16282             0             0              42         1  ...
# 16283             0             0              40         1  ...
# 16284          5178             0              60         0  ...
# ...             ...           ...             ...       ...  ...
# 48835          7688             0              40         1  ...
# 48836             0             0              40         1  ...
# 48837             0             0              40         0  ...
# 48838             0             0              25         1  ...
# 48839             0             0              50         1  ...
#
#        Rel_Not-in-family  Rel_Other-relative  Rel_Own-child  Rel_Unmarried  \
# Id
# 16280              False               False           True          False
# 16281              False               False          False          False
# 16282               True               False          False          False
# 16283               True               False          False          False
# 16284              False               False          False          False
# ...                  ...                 ...            ...            ...
# 48835              False               False          False          False
# 48836              False               False          False           True
# 48837              False               False           True          False
# 48838               True               False          False          False
# 48839               True               False          False          False
#
#        Rel_Wife  Race_Amer-Indian-Eskimo  Race_Asian-Pac-Islander  Race_Black  \
# Id
# 16280     False                    False                    False       False
# 16281     False                    False                    False       False
# 16282     False                    False                    False       False
# 16283     False                    False                    False       False
# 16284     False                    False                    False       False
# ...         ...                      ...                      ...         ...
# 48835     False                    False                    False       False
# 48836     False                    False                    False        True
# 48837     False                    False                    False       False
# 48838     False                    False                    False       False
# 48839     False                    False                    False       False
#
#        Race_Other  Race_White
# Id
# 16280       False        True
# 16281       False        True
# 16282       False        True
# 16283       False        True
# 16284       False        True
# ...           ...         ...
# 48835       False        True
# 48836       False       False
# 48837       False        True
# 48838       False        True
# 48839       False        True
#
# [30717 rows x 43 columns]

# %% [markdown]
# ### Modelo Cross-Validation

# %%
# Definindo parâmetros
cvFolds = 5
minCorr = 0.1
scores = ("accuracy", "f1")

trainData_dummies = pd.get_dummies(trainData, drop_first=True)
correlation = trainData_dummies.corr()

# %%
# Identificando colunas para remover, baseadas na correlação com "Target"
toRemove = correlation["Target"].where(correlation["Target"].abs() <= minCorr).dropna().index

# Separando features (X) e target (Y)
trainY = trainData["Target"]
trainX = trainData.drop("Target", axis=1)

# Garantir que estamos removendo apenas colunas que existem em trainX
toRemove_filtered = [col for col in toRemove if col in trainX.columns]

# Remover as colunas filtradas
trainX.drop(toRemove_filtered, axis=1, inplace=True)

# %%
trainX
# Out:
#        Age  isPrivate     Education  Education-num  isMale  Capital-gain  \
# Id
# 16280   34          1  Some-college             10     1.0             0
# 16281   58          0          10th              6     1.0             0
# 16282   25          1  Some-college             10     1.0             0
# 16283   24          1  Some-college             10     0.0             0
# 16284   57          0       HS-grad              9     1.0          5178
# ...    ...        ...           ...            ...     ...           ...
# 48835   42          1       Masters             14     1.0          7688
# 48836   23          1       HS-grad              9     0.0             0
# 48837   30          1       HS-grad              9     0.0             0
# 48838   18          1       HS-grad              9     0.0             0
# 48839   47          0     Bachelors             13     1.0             0
#
#        Capital-loss  Hours-per-week  Occ_Exec-managerial  Occ_Other-service  \
# Id
# 16280             0              44                 True              False
# 16281             0              40                False              False
# 16282             0              42                False              False
# 16283             0              40                False              False
# 16284             0              60                False              False
# ...             ...             ...                  ...                ...
# 48835             0              40                False              False
# 48836             0              40                False              False
# 48837             0              40                False              False
# 48838             0              25                False              False
# 48839             0              50                False              False
#
#        Occ_Prof-specialty  Mar_Divorced  Mar_Married-civ-spouse  \
# Id
# 16280               False          True                   False
# 16281               False         False                    True
# 16282               False         False                   False
# 16283               False          True                   False
# 16284               False         False                    True
# ...                   ...           ...                     ...
# 48835                True         False                    True
# 48836               False         False                   False
# 48837               False         False                   False
# 48838               False         False                   False
# 48839                True          True                   False
#
#        Mar_Never-married  Rel_Husband  Rel_Not-in-family  Rel_Own-child  \
# Id
# 16280              False        False              False           True
# 16281              False         True              False          False
# 16282               True        False               True          False
# 16283              False        False               True          False
# 16284              False         True              False          False
# ...                  ...          ...                ...            ...
# 48835              False         True              False          False
# 48836               True        False              False          False
# 48837               True        False              False           True
# 48838               True        False               True          False
# 48839              False        False               True          False
#
#        Rel_Unmarried  Rel_Wife
# Id
# 16280          False     False
# 16281          False     False
# 16282          False     False
# 16283          False     False
# 16284          False     False
# ...              ...       ...
# 48835          False     False
# 48836           True     False
# 48837          False     False
# 48838          False     False
# 48839          False     False
#
# [30717 rows x 19 columns]

# %% [markdown]
# ### KNN
